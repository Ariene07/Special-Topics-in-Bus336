# %%
# Deliverable One Task 

import pandas  as pd

df = pd.read_csv('Ariene_Starbucks_Project/BUS336_Signature_Term_Project_Starbucks_Beverage_Menu.csv')

# %%
# Deliverable Two Task 

#Task One: Check the total NaN enteries for all columns in the dataframe

nan_counts = df.isnull().sum()

print(nan_counts)
# Out:
# Product_Name           1
# Size                   1
# Milk                   1
# Whip                   1
# Serving_Size_ml        1
# Calories               1
# Total_Fat_g            1
# Saturated_Fat_g        2
# Trans_Fat_g            1
# Cholesterol_mg         1
# Sodium_mg              1
# Carbohydrates_g        1
# Dietary_Fiber_g        1
# Sugar_g                1
# Protein_g              1
# Vitamin_A_%DV          1
# Vitamin_C_%DV          1
# Calcium_%DV            1
# Iron_%DV               1
# Caffiene_milligrams    1
# dtype: int64

# %%
# Task Two: View the first 15 rows

print(df.head(15))
# Out:
#                                         Product_Name                Size  \
# 0                         Brewed Coffee - Dark Roast               Short
# 1                         Brewed Coffee - Dark Roast                Tall
# 2                         Brewed Coffee - Dark Roast              Grande
# 3                         Brewed Coffee - Dark Roast              Venti®
# 4                Brewed Coffee Traveler - Dark Roast  1 - 236 mL serving
# 5            Brewed Coffee - Decaf Pike Place® Roast               Short
# 6            Brewed Coffee - Decaf Pike Place® Roast                Tall
# 7            Brewed Coffee - Decaf Pike Place® Roast              Grande
# 8            Brewed Coffee - Decaf Pike Place® Roast              Venti®
# 9   Brewed Coffee Traveler - Decaf Pike Place® Roast  1 - 236 mL serving
# 10                      Brewed Coffee - Medium Roast               Short
# 11                                               NaN                 NaN
# ...

# %%
# Assign the dataframe to 'df1' and removethe rowwith all the blank enteries

df1 = df.dropna(how='all')

print(df1)
# Out:
#                              Product_Name                Size     Milk  \
# 0              Brewed Coffee - Dark Roast               Short  No Milk
# 1              Brewed Coffee - Dark Roast                Tall  No Milk
# 2              Brewed Coffee - Dark Roast              Grande  No Milk
# 3              Brewed Coffee - Dark Roast              Venti®  No Milk
# 4     Brewed Coffee Traveler - Dark Roast  1 - 236 mL serving  No Milk
# ...                                   ...                 ...      ...
# 1200                  White Hot Chocolate              Venti®    Whole
# 1201                  White Hot Chocolate              Venti®      Soy
# 1202                  White Hot Chocolate              Venti®      Soy
# 1203                  White Hot Chocolate              Venti®  Coconut
# 1204                  White Hot Chocolate              Venti®  Coconut
#
#          Whip  Serving_Size_ml  Calories  Total_Fat_g  Saturated_Fat_g  \
# ...

# %%
# Task Four: Validate that it has been removed by. running the 'isnull' and 'sum' functions

nan_counts_after_removal = df1.isnull().sum()

print(nan_counts_after_removal)
# Out:
# Product_Name           0
# Size                   0
# Milk                   0
# Whip                   0
# Serving_Size_ml        0
# Calories               0
# Total_Fat_g            0
# Saturated_Fat_g        1
# Trans_Fat_g            0
# Cholesterol_mg         0
# Sodium_mg              0
# Carbohydrates_g        0
# Dietary_Fiber_g        0
# Sugar_g                0
# Protein_g              0
# Vitamin_A_%DV          0
# Vitamin_C_%DV          0
# Calcium_%DV            0
# Iron_%DV               0
# Caffiene_milligrams    0
# dtype: int64

# %%
# Deliverable Three Task 

# Task One: Check columns, NaN counts, and data types 

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1204 entries, 0 to 1204
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Product_Name         1204 non-null   object
#  1   Size                 1204 non-null   object
#  2   Milk                 1204 non-null   object
#  3   Whip                 1204 non-null   object
#  4   Serving_Size_ml      1204 non-null   float64
#  5   Calories             1204 non-null   float64
#  6   Total_Fat_g          1204 non-null   float64
#  7   Saturated_Fat_g      1203 non-null   float64
#  8   Trans_Fat_g          1204 non-null   float64
#  9   Cholesterol_mg       1204 non-null   float64
#  10  Sodium_mg            1204 non-null   float64
#  11  Carbohydrates_g      1204 non-null   float64
#  12  Dietary_Fiber_g      1204 non-null   float64
#  13  Sugar_g              1204 non-null   object
#  14  Protein_g            1204 non-null   float64
# ...

# %%
# Task Two: Convert 'Sugar_g' column to float 

df1 = df.copy(deep=True)

df1.loc[df1.index[1],'Sugar_g'] = 0

df1['Sugar_g'] = df1['Sugar_g'].astype(float)

# %%
# Task Three: Validate that the 'Sugar_g' variable has been changed to float

sugar_dtype = df1['Sugar_g'].dtype

print(sugar_dtype)
# Out:
# float64

# %%
# Deliverable Four Task

# Task One: Using the 'info' function, determine the column in the 'df1' dataframe with an entry that still has one NaN value 

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1205 entries, 0 to 1204
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Product_Name         1204 non-null   object
#  1   Size                 1204 non-null   object
#  2   Milk                 1204 non-null   object
#  3   Whip                 1204 non-null   object
#  4   Serving_Size_ml      1204 non-null   float64
#  5   Calories             1204 non-null   float64
#  6   Total_Fat_g          1204 non-null   float64
#  7   Saturated_Fat_g      1203 non-null   float64
#  8   Trans_Fat_g          1204 non-null   float64
#  9   Cholesterol_mg       1204 non-null   float64
#  10  Sodium_mg            1204 non-null   float64
#  11  Carbohydrates_g      1204 non-null   float64
#  12  Dietary_Fiber_g      1204 non-null   float64
#  13  Sugar_g              1204 non-null   float64
#  14  Protein_g            1204 non-null   float64
# ...

# %%
# Task Two: Assign 'df2' and remove the row with NaN entry 

df2 = df1.dropna()

# %%
# Task Three: 

df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1203 entries, 0 to 1204
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Product_Name         1203 non-null   object
#  1   Size                 1203 non-null   object
#  2   Milk                 1203 non-null   object
#  3   Whip                 1203 non-null   object
#  4   Serving_Size_ml      1203 non-null   float64
#  5   Calories             1203 non-null   float64
#  6   Total_Fat_g          1203 non-null   float64
#  7   Saturated_Fat_g      1203 non-null   float64
#  8   Trans_Fat_g          1203 non-null   float64
#  9   Cholesterol_mg       1203 non-null   float64
#  10  Sodium_mg            1203 non-null   float64
#  11  Carbohydrates_g      1203 non-null   float64
#  12  Dietary_Fiber_g      1203 non-null   float64
#  13  Sugar_g              1203 non-null   float64
#  14  Protein_g            1203 non-null   float64
# ...

# %%
# Deliverable Five 

#Task One: Rename column heeader in 'df3'

df3 = df2.rename(columns={'Caffiene_milligrams': 'Caffiene_mg'})

# %%
# Task Two: Validate the column name change 

df3.head()
# Out:
#                           Product_Name                Size     Milk     Whip  \
# 0           Brewed Coffee - Dark Roast               Short  No Milk  No Whip
# 1           Brewed Coffee - Dark Roast                Tall  No Milk  No Whip
# 2           Brewed Coffee - Dark Roast              Grande  No Milk  No Whip
# 3           Brewed Coffee - Dark Roast              Venti®  No Milk  No Whip
# 4  Brewed Coffee Traveler - Dark Roast  1 - 236 mL serving  No Milk  No Whip
#
#    Serving_Size_ml  Calories  Total_Fat_g  Saturated_Fat_g  Trans_Fat_g  \
# 0            236.0       3.0          0.1              0.0          0.0
# 1            354.0       4.0          0.1              0.0          0.0
# 2            473.0       5.0          0.1              0.0          0.0
# 3            591.0       5.0          0.1              0.0          0.0
# 4            236.0       3.0          0.1              0.0          0.0
#
# ...

# %%
# Deliverable Six Tasks

# Task One: Use the 'describe()' function to describe the continuous variables 

continuous_description = df3.describe().round(2)

print(continuous_description)
# Out:
#        Serving_Size_ml  Calories  Total_Fat_g  Saturated_Fat_g  Trans_Fat_g  \
# count          1203.00   1203.00      1203.00          1203.00      1203.00
# mean            464.70    230.83         6.37             3.98         0.12
# std             159.72    132.05         5.89             3.99         0.15
# min             236.00      0.00         0.00             0.00         0.00
# 25%             354.00    140.00         1.50             0.30         0.00
# 50%             473.00    220.00         5.00             3.00         0.00
# 75%             591.00    310.00        10.00             7.00         0.20
# max             887.00    640.00        28.00            20.00         0.50
#
#        Cholesterol_mg  Sodium_mg  Carbohydrates_g  Dietary_Fiber_g  Sugar_g  \
# count         1203.00    1203.00          1203.00          1203.00  1203.00
# mean            15.55     142.82            37.59             0.86    34.95
# ...

# %%
#Task Two: Use 'discribe()' function to describe categorical variables 

categorical_description = df3.describe(include='object')

print(categorical_description)
# Out:
#                Product_Name    Size    Milk     Whip
# count                  1203    1203    1203     1203
# unique                   94       7       6        2
# top     White Hot Chocolate  Grande  Nonfat  No Whip
# freq                     50     345     240      910

# %%
# Continuous variables provide measures of central tendency and dispersion.
# Mean, median, standard deviation, and range can be observed.
# These measures help understand the distribution and spread of data.
# Categorical variables provide information on frequency and unique counts.
# Mode and frequency distribution can be observed.
# This helps understand the most common categories and their distribution.

# %%
# Deliverable Seven Tasks

# Task One: Using the 'to_cvs' function, write dataframe 'df3' to a new 'df4.cvs' file

df3.to_csv('df4.csv', index=False)

# %%
# Task Three: Load 'df4.csv' bsck into. new dataframe 

df4 = pd.read_csv('Ariene_Starbucks_Project/df4.csv')

# %%
df4.head()
# Out:
#                           Product_Name                Size     Milk     Whip  \
# 0           Brewed Coffee - Dark Roast               Short  No Milk  No Whip
# 1           Brewed Coffee - Dark Roast                Tall  No Milk  No Whip
# 2           Brewed Coffee - Dark Roast              Grande  No Milk  No Whip
# 3           Brewed Coffee - Dark Roast              Venti®  No Milk  No Whip
# 4  Brewed Coffee Traveler - Dark Roast  1 - 236 mL serving  No Milk  No Whip
#
#    Serving_Size_ml  Calories  Total_Fat_g  Saturated_Fat_g  Trans_Fat_g  \
# 0            236.0       3.0          0.1              0.0          0.0
# 1            354.0       4.0          0.1              0.0          0.0
# 2            473.0       5.0          0.1              0.0          0.0
# 3            591.0       5.0          0.1              0.0          0.0
# 4            236.0       3.0          0.1              0.0          0.0
#
# ...
